# %% [markdown]
# Select Catalog

# %%
# %sql
USE CATALOG baraa_projectwork

# %% [markdown]
# Create Lakehouse schemas

# %%
# %sql 
create schema if not exists bronze
comment 'Bronze layer: raw ingested data';
     
create schema if not exists silver
comment 'Silver layer: cleansed and transformed data';
     
create schema if not exists gold
comment 'Gold layer: business-ready data';

# %% [markdown]
# Create Volume

# %%
# %sql 
create volume if not exists baraa_projectwork.bronze.raw_source_systems
comment 'Volume for raw source files (.csv)'
