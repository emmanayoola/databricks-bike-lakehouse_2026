# %% [markdown]
# config file to host file folder name, files path and table for the data to be written to

# %%
data_config = [
    {
        "source": "crm",
        "file_path": "/Volumes/baraa_projectwork/bronze/raw_source_systems/source_crm/cust_info.csv",
        "table": "crm_cust_info"
    },
    {
        "source": "crm",
        "file_path": "/Volumes/baraa_projectwork/bronze/raw_source_systems/source_crm/prd_info.csv",
        "table": "crm_prd_info"
    },
    {
        "source": "crm",
        "file_path": "/Volumes/baraa_projectwork/bronze/raw_source_systems/source_crm/sales_details.csv",
        "table": "crm_sales_details"
    },
    {
        "source": "erp",
        "file_path": "/Volumes/baraa_projectwork/bronze/raw_source_systems/source_erp/CUST_AZ12.csv",
        "table": "erp_cust_az12"
    },
    {
        "source": "erp",
        "file_path": "/Volumes/baraa_projectwork/bronze/raw_source_systems/source_erp/LOC_A101.csv",
        "table": "erp_loc_a101"
    },
    {
        "source": "erp",
        "file_path": "/Volumes/baraa_projectwork/bronze/raw_source_systems/source_erp/PX_CAT_G1V2.csv",
        "table": "erp_px_cat_g1v2"
    }
]

data_config

# %%
for item in data_config:
    print(f"Ingesting {item['source']} to baraa_projectwork.bronze.{item['table']}")

    df = (
        spark.read
            .option("header", "true")
            .option("inferSchema", "true")
            .csv(item["file_path"])
    )
    (df.write \
        .mode("overwrite") \
        .format("delta") \
        .saveAsTable(f"baraa_projectwork.bronze.{item['table']}")
        )
    print("Success\n")
